# %% [markdown]
# <a href="https://colab.research.google.com/github/ausamaps/Kobo-Clon-Platform/blob/main/chatboot_whats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
